# %%
from bs4 import BeautifulSoup

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
url=('https://nanoreview.net/en/soc-list/rating')

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(response.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>Smartphone Processors Ranking List [2023] - NanoReview</title>
# <meta content="See our mobile processors performance ranking based on real-world tests in games, apps, and benchmarks (like AnTuTu / GeekBench)." name="description"/>
# <meta content="Smartphone Processors Ranking List [2023] - NanoReview" property="og:title"/>
# <meta content="See our mobile processors performance ranking based on real-world tests in games, apps, and benchmarks (like AnTuTu / GeekBench)." property="og:description"/>
# <meta content="NanoReview.net" property="og:site_name"/>
# <meta content="https://nanoreview.net/en/soc-list/rating" property="og:url"/>
# <link href="https://nanoreview.net/en/soc-list/rating" rel="canonical"/>
# ...

# %%
processor=soup.select(".table-list a")

# %%
processor
# Out:
# [<a href="/en/soc/apple-a16-bionic" style="font-weight:500;">A16 Bionic</a>,
#  <a href="/en/soc/qualcomm-snapdragon-8-gen-2" style="font-weight:500;">Snapdragon 8 Gen 2</a>,
#  <a href="/en/soc/mediatek-dimensity-9200" style="font-weight:500;">Dimensity 9200</a>,
#  <a href="/en/soc/apple-a15-bionic" style="font-weight:500;">A15 Bionic</a>,
#  <a href="/en/soc/mediatek-dimensity-9000-plus" style="font-weight:500;">Dimensity 9000 Plus</a>,
#  <a href="/en/soc/snapdragon-8-plus-gen-1" style="font-weight:500;">Snapdragon 8 Plus Gen 1</a>,
#  <a href="/en/soc/mediatek-dimensity-9000" style="font-weight:500;">Dimensity 9000</a>,
#  <a href="/en/soc/qualcomm-snapdragon-8-gen-1" style="font-weight:500;">Snapdragon 8 Gen 1</a>,
#  <a href="/en/soc/apple-a14-bionic" style="font-weight:500;">A14 Bionic</a>,
#  <a href="/en/soc/samsung-exynos-2200" style="font-weight:500;">Exynos 2200</a>,
#  <a href="/en/soc/mediatek-dimensity-8200" style="font-weight:500;">Dimensity 8200</a>,
# ...

# %%
rating=soup.select(".table-list-score-box")

# %%
rating
# Out:
# [<div class="table-list-score-box" style="border: 1px solid #028612; color: #028612; width: 32px;">99</div>,
#  <div class="table-list-score-box" style="border: 1px solid #028612; color: #028612; width: 32px;">97</div>,
#  <div class="table-list-score-box" style="border: 1px solid #028612; color: #028612; width: 32px;">95</div>,
#  <div class="table-list-score-box" style="border: 1px solid #028612; color: #028612; width: 32px;">94</div>,
#  <div class="table-list-score-box" style="border: 1px solid #028612; color: #028612; width: 32px;">93</div>,
#  <div class="table-list-score-box" style="border: 1px solid #028612; color: #028612; width: 32px;">93</div>,
#  <div class="table-list-score-box" style="border: 1px solid #028612; color: #028612; width: 32px;">91</div>,
#  <div class="table-list-score-box" style="border: 1px solid #028612; color: #028612; width: 32px;">90</div>,
#  <div class="table-list-score-box" style="border: 1px solid #028612; color: #028612; width: 32px;">86</div>,
# ...

# %%
gpu=soup.select("td:nth-child(8) div")

# %%
gpu
# Out:
# [<div style="width: 90px; white-space: normal;">Apple GPU</div>,
#  <div style="width: 90px; white-space: normal;">Adreno 740</div>,
#  <div style="width: 90px; white-space: normal;">Mali-G715 Immortalis MC11</div>,
#  <div style="width: 90px; white-space: normal;">Apple GPU</div>,
#  <div style="width: 90px; white-space: normal;">Mali-G710 MC10</div>,
#  <div style="width: 90px; white-space: normal;">Adreno 730</div>,
#  <div style="width: 90px; white-space: normal;">Mali-G710</div>,
#  <div style="width: 90px; white-space: normal;">Adreno 730</div>,
#  <div style="width: 90px; white-space: normal;">Apple GPU</div>,
#  <div style="width: 90px; white-space: normal;">Samsung Xclipse 920</div>,
#  <div style="width: 90px; white-space: normal;">Mali-G610 MC6</div>,
#  <div style="width: 90px; white-space: normal;">Adreno 660</div>,
#  <div style="width: 90px; white-space: normal;">Adreno 660</div>,
#  <div style="width: 90px; white-space: normal;">Mali-G610 MC6</div>,
# ...

# %%
import pandas

# %%
phoneprocessor=pandas.DataFrame(processor,columns=['phone processor'])

# %%
phoneprocessor
# Out:
#          phone processor rating                          gpu
# 0             A16 Bionic   [99]                  [Apple GPU]
# 1     Snapdragon 8 Gen 2   [97]                 [Adreno 740]
# 2         Dimensity 9200   [95]  [Mali-G715 Immortalis MC11]
# 3             A15 Bionic   [94]                  [Apple GPU]
# 4    Dimensity 9000 Plus   [93]             [Mali-G710 MC10]
# ..                   ...    ...                          ...
# 145            Helio X20   [21]              [Mali-T880 MP4]
# 146            Helio P22   [21]             [PowerVR GE8320]
# 147       Snapdragon 450   [21]                 [Adreno 506]
# 148            Helio A22   [21]             [PowerVR GE8320]
# 149            Kirin 659   [20]            [Mali-T830 MP2\t]
#
# [150 rows x 3 columns]

# %%
phoneprocessor["rating"]=rating
phoneprocessor["gpu"]=gpu

# %%
phoneprocessor
# Out:
#          phone processor rating                          gpu
# 0             A16 Bionic   [99]                  [Apple GPU]
# 1     Snapdragon 8 Gen 2   [97]                 [Adreno 740]
# 2         Dimensity 9200   [95]  [Mali-G715 Immortalis MC11]
# 3             A15 Bionic   [94]                  [Apple GPU]
# 4    Dimensity 9000 Plus   [93]             [Mali-G710 MC10]
# ..                   ...    ...                          ...
# 145            Helio X20   [21]              [Mali-T880 MP4]
# 146            Helio P22   [21]             [PowerVR GE8320]
# 147       Snapdragon 450   [21]                 [Adreno 506]
# 148            Helio A22   [21]             [PowerVR GE8320]
# 149            Kirin 659   [20]            [Mali-T830 MP2\t]
#
# [150 rows x 3 columns]

# %%
# Out:
#          phone processor rating                          gpu
# 0             A16 Bionic   [99]                  [Apple GPU]
# 1     Snapdragon 8 Gen 2   [97]                 [Adreno 740]
# 2         Dimensity 9200   [95]  [Mali-G715 Immortalis MC11]
# 3             A15 Bionic   [94]                  [Apple GPU]
# 4    Dimensity 9000 Plus   [93]             [Mali-G710 MC10]
# ..                   ...    ...                          ...
# 145            Helio X20   [21]              [Mali-T880 MP4]
# 146            Helio P22   [21]             [PowerVR GE8320]
# 147       Snapdragon 450   [21]                 [Adreno 506]
# 148            Helio A22   [21]             [PowerVR GE8320]
# 149            Kirin 659   [20]            [Mali-T830 MP2\t]
#
# [150 rows x 3 columns]

# %%
phoneprocessor.to_csv("C:\\Users\\aedpu\\OneDrive\\Documents\\bassith17 (bsc cs 'b').csv")
